# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'C:\Users\Home\Downloads\Admission_Predict.csv')
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.tail(5)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
data.shape
# Out:
# (400, 9)

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
data=data.drop(columns=['Serial No.'])

# %%
data.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# ...

# %%
plt.figure(figsize=(20,35),facecolor='yellow')
plotnumber=1
for column in data:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=15)
        plotnumber+=1
        plt.show

# %%
#its normally distrbuted

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
y=data['Chance of Admit ']
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
x=data.drop(columns=['Chance of Admit '])
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
print(data.columns)# to check the column names
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)#transforming data of x into standard format.....stamdardisation
x_scaled
# Out:
# array([[ 1.76210664,  1.74697064,  0.79882862, ...,  1.16732114,
#          1.76481828,  0.90911166],
#        [ 0.62765641, -0.06763531,  0.79882862, ...,  1.16732114,
#          0.45515126,  0.90911166],
#        [-0.07046681, -0.56252785, -0.07660001, ...,  0.05293342,
#         -1.00563118,  0.90911166],
#        ...,
#        [ 1.15124883,  1.41704229,  0.79882862, ...,  1.16732114,
#          1.42900622,  0.90911166],
#        [-0.41952842, -0.72749202, -0.07660001, ...,  0.61012728,
#          0.30403584, -1.09997489],
#        [ 1.41304503,  1.58200646,  0.79882862, ...,  0.61012728,
#          1.78160888,  0.90911166]])

# %%
#SPLITTING DATA INTO TEST AND TRAIN
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=.25,random_state=300)
y_train.head()
#RANDOM CHECK FOR DATA CORRECTNESS
# Out:
# 40     0.46
# 138    0.80
# 292    0.56
# 318    0.79
# 100    0.71
# Name: Chance of Admit , dtype: float64

# %%
#SPLITTING DATA INTO TEST AND TRAIN
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=.25,random_state=250)
y_train.head()
#RANDOM CHECK FOR DATA CORRECTNESS
# Out:
# 20     0.64
# 46     0.86
# 196    0.73
# 29     0.54
# 82     0.92
# Name: Chance of Admit , dtype: float64

# %% [markdown]
# MODEL BLDG

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)
#I WILL BUILD MODEL USING ONLY TRAIN MODEL
# Out:
# LinearRegression()

# %% [markdown]
# MODEL PREDICTION

# %%
print("Chance of Admit for this student is :",regression.predict(scaler.transform([[324,110,3,3.5,3.5,9.04,1]])))
# Out:
# Chance of Admit for this student is : [0.81520557]

# %% [markdown]
# SAVING MODEL

# %%
pickle.dump(regression,open('reg_model','wb'))

# %% [markdown]
# MODEL TESTING

# %%
regression.score(x_train,y_train)
# Out:
# 0.7929869457236408

# %%
regression.score(x_test,y_test)
# Out:
# 0.8208356044239843
